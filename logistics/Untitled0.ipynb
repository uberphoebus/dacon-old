# %%
list = [1, 4, 2, 3]

# %%
a = str(list).strip('[').strip(']').replace(',', '')
print(a)
# Out:
# 1 4 2 3

# %%
a, b = map(int, '0 0'.split())

# %%
input = '5 2'

# %%
input != '0 0'
# Out:
# True
