# %% [markdown]
# # read

# %%
import pandas as pd; pd.set_option('display.max_columns', None)
import numpy as np
import warnings; warnings.filterwarnings(action='ignore')
from tqdm import tqdm

train = pd.read_csv('./data/train.csv')
test  = pd.read_csv('./data/test.csv')
sub   = pd.read_csv('./data/sample_submission.csv')

# %%
train.shape, test.shape, sub.shape
# Out:
# ((501951, 35), (46404, 34), (46404, 2))

# %%
train
# Out:
#             id  d_l_match_yn  d_m_match_yn  d_s_match_yn  h_l_match_yn  \
# 0            0          True          True          True         False
# 1            1         False         False         False          True
# 2            2         False         False         False          True
# 3            3         False         False         False          True
# 4            4          True          True          True         False
# ...        ...           ...           ...           ...           ...
# 501946  501946         False         False         False          True
# 501947  501947          True          True         False          True
# 501948  501948          True          True          True          True
# 501949  501949          True         False         False          True
# 501950  501950          True          True          True          True
#
#         h_m_match_yn  h_s_match_yn  person_attribute_a  person_attribute_a_1  \
# 0              False         False                   1                     4
# 1               True         False                   1                     3
# 2              False         False                   2                     0
# 3              False         False                   2                     0
# 4              False         False                   1                     3
# ...              ...           ...                 ...                   ...
# 501946         False         False                   1                     1
# 501947         False         False                   1                     6
# 501948         False         False                   1                     7
# 501949         False         False                   1                     1
# 501950         False         False                   1                     6
#
#         person_attribute_b  person_prefer_c  person_prefer_d_1  \
# 0                        3                5                275
# 1                        4                1                114
# 2                        3                5                464
# 3                        2                5                703
# 4                        4                5                275
# ...                    ...              ...                ...
# 501946                   2                2               1192
# 501947                   2                1                118
# 501948                   4                1                147
# 501949                   2                1                 46
# 501950                   3                5                147
#
#         person_prefer_d_2  person_prefer_d_3  person_prefer_e  \
# 0                     370                369                8
# 1                     181                175                4
# 2                     175                452                3
# 3                     705                704                3
# 4                     370                369                4
# ...                   ...                ...              ...
# 501946                935               1228                3
# 501947                113                110                4
# 501948                 46                145                4
# 501949                147                145                4
# 501950                 46                145                6
#
#         person_prefer_f  person_prefer_g  person_prefer_h_1  \
# 0                     1                1                  4
# 1                     1                1                131
# 2                     1                1                 54
# 3                     1                1                 72
# 4                     1                1                214
# ...                 ...              ...                ...
# 501946                1                1                 59
# 501947                1                1                105
# 501948                1                1                 59
# 501949                1                1                251
# 501950                1                1                278
#
#         person_prefer_h_2  person_prefer_h_3  contents_attribute_i  \
# 0                      95                 59                     3
# 1                     101                 96                     1
# 2                     263                 56                     3
# 3                     227                  2                     1
# 4                     210                209                     1
# ...                   ...                ...                   ...
# 501946                  4                 95                     3
# 501947                142                 95                     3
# 501948                127                139                     3
# 501949                 49                258                     3
# 501950                 31                 49                     3
#
#         contents_attribute_a  contents_attribute_j_1  contents_attribute_j  \
# 0                          3                      10                     2
# 1                          3                       5                     1
# 2                          1                      10                     2
# 3                          3                       5                     1
# 4                          1                      10                     2
# ...                      ...                     ...                   ...
# 501946                     3                       5                     1
# 501947                     3                      10                     2
# 501948                     1                       5                     1
# 501949                     2                       5                     1
# 501950                     3                       5                     1
#
#         contents_attribute_c  contents_attribute_k  contents_attribute_l  \
# 0                          1                     2                  1608
# 1                          1                     2                  1608
# 2                          1                     1                  1600
# 3                          1                     2                  1608
# 4                          1                     2                  1608
# ...                      ...                   ...                   ...
# 501946                     1                     2                   354
# 501947                     1                     2                   163
# 501948                     1                     2                   438
# 501949                     1                     2                   660
# 501950                     1                     2                   786
#
#         contents_attribute_d  contents_attribute_m  contents_attribute_e  \
# 0                        275                     1                     4
# 1                        275                     1                     4
# 2                         94                     1                     4
# 3                        275                     5                     3
# 4                        275                     1                     4
# ...                      ...                   ...                   ...
# 501946                   147                     1                     5
# 501947                   120                     1                     4
# 501948                   147                     2                     7
# 501949                   147                     3                     4
# 501950                   147                     2                     5
#
#         contents_attribute_h  person_rn  contents_rn     contents_open_dt  \
# 0                        139     618822       354805  2020-01-17 12:09:36
# 1                        133     571659       346213  2020-06-18 17:48:52
# 2                         53     399816       206408  2020-07-08 20:00:10
# 3                         74     827967       572323  2020-01-13 18:09:34
# 4                         74     831614       573899  2020-03-09 20:39:22
# ...                      ...        ...          ...                  ...
# 501946                    65     503156       285850  2020-03-13 12:55:52
# 501947                   142     676255       456996  2020-01-20 11:51:51
# 501948                    65     484528       293258  2020-08-05 17:27:24
# 501949                   259     456330       273797  2020-06-15 09:23:21
# 501950                   289     235596       176650  2020-05-25 14:34:48
#
#         target
# 0            1
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 501946       1
# 501947       1
# 501948       1
# 501949       1
# 501950       1
#
# [501951 rows x 35 columns]

# %%
test
# Out:
#           id  d_l_match_yn  d_m_match_yn  d_s_match_yn  h_l_match_yn  \
# 0          0          True         False         False          True
# 1          1         False         False         False          True
# 2          2          True         False         False          True
# 3          3          True         False         False          True
# 4          4          True         False         False          True
# ...      ...           ...           ...           ...           ...
# 46399  46399          True          True          True         False
# 46400  46400          True         False         False          True
# 46401  46401          True          True         False          True
# 46402  46402          True          True         False          True
# 46403  46403          True          True         False          True
#
#        h_m_match_yn  h_s_match_yn  person_attribute_a  person_attribute_a_1  \
# 0              True          True                   1                     1
# 1             False         False                   2                     0
# 2              True          True                   2                     3
# 3              True          True                   1                     2
# 4             False         False                   1                     6
# ...             ...           ...                 ...                   ...
# 46399         False         False                   2                     0
# 46400         False         False                   2                     0
# 46401          True          True                   2                     0
# 46402          True          True                   1                     3
# 46403          True          True                   1                     2
#
#        person_attribute_b  person_prefer_c  person_prefer_d_1  \
# 0                       2                1                857
# 1                       2                2                683
# 2                       2                1                514
# 3                       2                5                114
# 4                       4                5               1082
# ...                   ...              ...                ...
# 46399                   4                1                147
# 46400                   4                1                176
# 46401                   3                1                145
# 46402                   3                2                145
# 46403                   4                1                145
#
#        person_prefer_d_2  person_prefer_d_3  person_prefer_e  person_prefer_f  \
# 0                    851               1227                4                1
# 1                   1086                662                2                1
# 2                    790               1233                0                1
# 3                    181                175                4                1
# 4                   1078               1056                5                1
# ...                  ...                ...              ...              ...
# 46399                 46                145                4                1
# 46400                120                159                4                1
# 46401                 46                147                5                1
# 46402                 46                147                6                1
# 46403                 46                147                0                1
#
#        person_prefer_g  person_prefer_h_1  person_prefer_h_2  \
# 0                    1                263                 56
# 1                    1                258                263
# 2                    1                177                170
# 3                    1                177                170
# 4                    1                178                177
# ...                ...                ...                ...
# 46399                1                  2                  4
# 46400                1                 86                 31
# 46401                1                288                279
# 46402                1                288                279
# 46403                1                288                280
#
#        person_prefer_h_3  contents_attribute_i  contents_attribute_a  \
# 0                     49                     1                     3
# 1                     49                     1                     3
# 2                    171                     3                     3
# 3                    171                     3                     3
# 4                      4                     3                     1
# ...                  ...                   ...                   ...
# 46399                 95                     3                     3
# 46400                278                     3                     3
# 46401                278                     3                     3
# 46402                278                     3                     1
# 46403                283                     3                     1
#
#        contents_attribute_j_1  contents_attribute_j  contents_attribute_c  \
# 0                          10                     2                     1
# 1                           5                     1                     1
# 2                           3                     1                     1
# 3                           5                     1                     1
# 4                           5                     1                     1
# ...                       ...                   ...                   ...
# 46399                       5                     1                     1
# 46400                      10                     2                     1
# 46401                      10                     2                     1
# 46402                       5                     1                     3
# 46403                       5                     1                     1
#
#        contents_attribute_k  contents_attribute_l  contents_attribute_d  \
# 0                         2                  1147                   839
# 1                         2                  1611                   278
# 2                         2                  1817                   490
# 3                         2                   101                   150
# 4                         1                   985                  1097
# ...                     ...                   ...                   ...
# 46399                     2                   759                   147
# 46400                     2                   759                   147
# 46401                     2                   759                   147
# 46402                     2                   759                   147
# 46403                     2                   759                   147
#
#        contents_attribute_m  contents_attribute_e  contents_attribute_h  \
# 0                         1                     5                   263
# 1                         1                     4                   263
# 2                         3                     4                   177
# 3                         5                     3                   177
# 4                         1                     4                   177
# ...                     ...                   ...                   ...
# 46399                     1                     5                    91
# 46400                     1                     4                    91
# 46401                     1                     4                   288
# 46402                     1                     5                   288
# 46403                     2                     5                   288
#
#        person_rn  contents_rn     contents_open_dt
# 0         393790       236865  2020-12-01 02:24:18
# 1         394058       236572  2020-12-17 05:42:53
# 2        1002061       704612  2020-12-10 23:33:41
# 3        1000813       704652  2020-12-03 19:44:55
# 4         111146       704413  2020-12-11 21:24:34
# ...          ...          ...                  ...
# 46399     425040       726084  2020-12-17 01:06:26
# 46400     290061       156948  2020-12-29 21:57:25
# 46401     307951       175069  2020-12-10 19:09:09
# 46402     308354       174849  2020-12-07 14:04:34
# 46403     309401       173406  2020-12-22 16:43:39
#
# [46404 rows x 34 columns]

# %% [markdown]
# # drop

# %%
drop_cols = ['id', 'contents_open_dt']
train.drop(drop_cols, axis=1, inplace=True)
test.drop(drop_cols, axis=1, inplace=True)

# %% [markdown]
# # modeling

# %%
X = train.drop('target', axis=1)
y = train['target']

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(
    n_estimators=300,
    max_depth=60, 
    n_jobs=-1
)

model.fit(X, y)
# Out:
# RandomForestClassifier(max_depth=60, n_estimators=300, n_jobs=-1)

# %% [markdown]
# # sub

# %%
sub['target'] = model.predict(test)
sub.head()
# Out:
#    id  target
# 0   0       1
# 1   1       0
# 2   2       0
# 3   3       1
# 4   4       0

# %%
# sub.to_csv('./sub/job_baseline.csv', index=False)
