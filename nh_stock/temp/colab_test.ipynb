# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
iem = pd.read_csv('/content/drive/MyDrive/venv/_pkg/dacon/nh_stock_hold/iem_info_20210902.csv')

# %%
# Out:
#        iem_cd             iem_krl_nm  ...  mkt_pr_tal_scl_tp_cd  stk_dit_cd
# 0     A000020                   동화약품  ...                     2          99
# 1     A000080                  하이트진로  ...                     2           1
# 2     A000180                 성창기업지주  ...                     3          99
# 3     A000227                유유제약2우B  ...                    99          99
# 4     A000325                 노루홀딩스우  ...                    99          99
# ...       ...                    ...  ...                   ...         ...
# 3074  A383310               에코프로에이치엔  ...                    99          99
# 3075  A385520         KODEX K-미래차액티브  ...                    99          99
# 3076  A388280         KBSTAR Fn컨택트대표  ...                    99          99
# 3077  A388420      KBSTAR 비메모리반도체액티브  ...                    99          99
# 3078  A394350  KOSEF 릭소글로벌퓨처모빌리티MSCI  ...                    99          99
#
# [3079 rows x 5 columns]
